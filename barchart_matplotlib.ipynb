# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
company =['Google' ,'Amazon' ,'Pepsi','Infosis']
revenue =[90,75,89,50]

# %%
plt.bar(company,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
ypos =np.arange(len(company))
ypos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(ypos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(ypos,company)
plt.bar(ypos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(ypos,company)
plt.ylabel('revenue($ billion)')
plt.title('Us Tech Comapny Stock')
plt.bar(ypos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(ypos,company)
plt.ylabel('revenue($ billion)')
plt.title('Us Tech Comapny Stock')
plt.bar(ypos,revenue ,label="Revenue")
plt.legend()

# %%
plt.xticks(ypos,company)
plt.ylabel('revenue($ billion)')
plt.title('Us Tech Comapny Stock')
plt.bar(ypos,revenue ,label="Revenue")
plt.bar(ypos ,profit ,label='Profit')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-4d05a160e40c> in <module>
#       3 plt.title('Us Tech Comapny Stock')
#       4 plt.bar(ypos,revenue ,label="Revenue")
# ----> 5 plt.bar(ypos ,profit ,label='Profit')
#       6 plt.legend()
#
# NameError: name 'profit' is not defined

# %%
plt.xticks(ypos,company)
plt.ylabel('revenue($ billion)')
plt.title('Us Tech Comapny Stock')
plt.bar(ypos-0.2,revenue ,width=0.4 ,label="Revenue")
plt.bar(ypos+0.2 ,profit,width=0.4,label='Profit')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-5a64e84b4bbe> in <module>
#       3 plt.title('Us Tech Comapny Stock')
#       4 plt.bar(ypos-0.2,revenue ,width=0.4 ,label="Revenue")
# ----> 5 plt.bar(ypos+0.2 ,profit,width=0.4,label='Profit')
#       6 plt.legend()
#
# NameError: name 'profit' is not defined
